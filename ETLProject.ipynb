# %%
import pandas as pd
import requests as r
import sqlalchemy
import time
pd.options.display.max_columns = None

# !kaggle datasets download -d palanjali007/amazons-top-50-bestselling-novels-20092020
# Out:
# Requirement already satisfied: kaggle in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (1.5.12)
# Requirement already satisfied: certifi in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: requests in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (2.25.1)
# Requirement already satisfied: urllib3 in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (1.26.4)
# Requirement already satisfied: six>=1.10 in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (4.0.1)
# Requirement already satisfied: tqdm in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (4.60.0)
# Requirement already satisfied: python-dateutil in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from kaggle) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from requests->kaggle) (4.0.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\brand\anaconda3\envs\pythondata\lib\site-packages (from python-slugify->kaggle) (1.3)
# Downloading amazons-top-50-bestselling-novels-20092020.zip to C:\Users\brand\repos\Homework\ETL-project
#   0%|          | 0.00/49.6k [00:00<?, ?B/s]
# 100%|##########| 49.6k/49.6k [00:00<00:00, 1.39MB/s]

# %%
# !unzip 'amazons-top-50-bestselling-novels-*.zip'
# Out:
# Archive:  amazons-top-50-bestselling-novels-20092020.zip
#   inflating: AmazonBooks - Sheet1.csv
#   inflating: AmazonBooks.xlsx

# %%
books_df=pd.read_csv('AmazonBooks - Sheet1.csv')
#after=""
#data=[]
#url="kaggle datasets download -d atahmasb/amazon-job-skills"
books_df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 595              Sean Hannity          4.8    20153     15  2020  Non Fiction
# 596              Sharon Jones          4.6    26423      8  2020  Non Fiction
# 597              Jennie Allen          4.7    12879     14  2020  Non Fiction
# 598              Katie Stokes          4.7    14128      5  2020  Non Fiction
# 599            Tara Westover           4.7    45351     11  2020  Non Fiction
#
# [600 rows x 7 columns]

# %%
res = r.get(url, headers=user_agent).json()
